# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mp
import seaborn as sb

# %% [markdown]
# firstly the libraries have been imported above                                                      #  ABHISHEK GUPTA

# %%
# fetching the data from the csv file
data = pd.read_csv(r'C:\Users\abhis\Downloads\StudentsPerformance (1) (1).csv')

# %% [markdown]
# now the csv file is being imported using the pandas

# %%
# check if the data has some missing values
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
#check the datatype of all the column values
data.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
#analyze the values of the columns and check whether they are numerical or categorical
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# firstly analysing the count of the males and female in the data set we found that they are approx SAME.//

# %%
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %% [markdown]
# count the level of education of the parents and we found that the parents having master degreee is lowest in the data
# set and the parents having the largest is having some college education

# %%
data['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
data['lunch'].value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %% [markdown]
# students having the standard lunch is more than the free/reduced

# %%
data['test preparation course'].value_counts()
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %% [markdown]
# #We can see from the above that the columns, “gender”, “parental level of education”, “race/ethnicity”, “lunch”, “test preparation course” are categorical variables.
#
# #Since marks are always numerical, therefore the columns, “math score”, “read score”, “write score” contain numerical values and hence are numerical variables.

# %%
#Adding columns “total” and “average” to the dataset.
data['total'] = data['math score'] + data['reading score'] + data['writing score']
data['average'] = data['total'] / 3

# %%
data.head(1000)
# successfully added the total and the average to the data set
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  total  \
# ...

# %%
# now we will plot the scores of the math using seaborn 
sb.distplot(data['math score'])

# %% [markdown]
# we came to know that the larger number of students scores between 60-80 in the mathematics

# %%
sb.distplot(data['reading score'])

# %% [markdown]
# we came to know that the larger number of students scores between 60-80 in the reading.

# %%
sb.distplot(data['writing score'])

# %% [markdown]
# we came to know that the larger number of students scores between 60-80 in the writing

# %%
sb.distplot(data['average'])

# %% [markdown]
# we came to know that the larger number of students average scores is between 60-80...///

# %%
sb.distplot(data['total'])

# %% [markdown]
# we came to know that the larger number of students total scores is between 195-230 .....//////

# %%
sb.pairplot(data)

# %%
# checking the genderwise data of individual subjects that give us the clear picture of intersts of the gender in diferent subjects
sb.barplot(data['gender'],data['math score'])
print(max(data['math score']))
# this show us that the average score of the male is better than the female even cloaser than the whole average of the data of math score
# Out:
# 100

# %% [markdown]
# # this show us that the average score of the male is better than the female even cloaser than the whole average of the data of math score..

# %%
sb.barplot(data['gender'],data['writing score'])
# as we all know the data has proved same that the average score of females is better than the male in writing part

# %% [markdown]
# # as we all know the data has proved same that the average score of females is better than the male in writing part

# %%
sb.barplot(data['gender'],data['reading score'])
# as we all know the data has proved same that the average score of females is better than the male in reading part
# so we came to know that the solving skills of male is better than the females averagely that depends upon gender.

# %% [markdown]
# # as we all know the data has proved same that the average score of females is better than the male in reading part
# # so we came to know that the solving skills of male is better than the females averagely that depends upon gender.

# %%
data['race/ethnicity'].value_counts().plot(kind='bar');
# we  have takena count of the race of the student we found the  studetns of group c are most and group A is lowest

# %% [markdown]
# # we  have taken a count of the race of the student we found the  students of group c are most and group A is lowest

# %%
# we are plotting the graph between the race and average score
sb.barplot(data['race/ethnicity'], data['average'])
# only from ethnicity we can make any decision some supporting variables will be needed we will  do ahead now.
# from group we found that the despite of most student s from group a , their average score is lowest and group E has maximum

# %% [markdown]
# from group we found that the despite of most student s from group a , their average score is lowest and group E has maximum

# %%
data['parental level of education'].value_counts().plot(kind='bar');
# student having some college parents education is most and the students with the master education is lowest..

# %% [markdown]
# student having some college parents education is most and the students with the master education is lowest..

# %%
sb.barplot(data['average'] , data['parental level of education'])
# from this plot we are able to find out that as the level of parental education decreases the average score of the student also decreases
# though the master's parents are lowest though their students have highest average score..
# this proves the impact of the parental eduvation in students performance.

# %% [markdown]
# 1. from this plot we are able to find out that as the level of parental education decreases the average score of the student also decreases
# 2. though the master's parents are lowest though their students have highest average score..
# 3. this proves the impact of the parental eduvation in students performance.

# %%
data['test preparation course'].value_counts().plot(kind='bar');
# studets having completed the course are very less than the students who havent done.....

# %% [markdown]
# # studets having completed the course are very less than the students who havent done.....

# %%
sb.barplot(data['test preparation course'], data['average'])
# this is preven from visulaization that the ,student who completed the preparation course they have better marks than others

# %% [markdown]
# # this is preven from visulaization that the ,student who completed the preparation course they have better marks than others

# %%
data['lunch'].value_counts().plot(kind='bar');
# students having the standard lunch is more than the ,free and reduced lunch.....

# %%
sb.barplot(data['lunch'], data['average'])
# from this it is clear that the students having standard luch are having more average score like directly related..

# %% [markdown]
# # analyze the data on the basis of the no. of students who failed or passed the exam

# %%
#analyze the data on the basis of the no. of students who failed or passed the exam
data['math_PassStatus'] = np.where(data['math score']<40, 'F', 'P')
data['read_PassStatus'] = np.where(data['reading score']<40, 'F', 'P')
data['write_PassStatus'] = np.where(data['writing score']<40, 'F', 'P')

# %%
data['math_PassStatus'].value_counts()
# Out:
# P    960
# F     40
# Name: math_PassStatus, dtype: int64

# %%
data['read_PassStatus'].value_counts()
# Out:
# P    974
# F     26
# Name: read_PassStatus, dtype: int64

# %%
data['write_PassStatus'].value_counts()
# Out:
# P    968
# F     32
# Name: write_PassStatus, dtype: int64

# %% [markdown]
# We came to know that the larger number of students are passed in subjects those who are failed more are in maths(40)
# and less in reading(26)

# %%
p = sb.countplot(y='parental level of education', data = data, hue='math_PassStatus', palette='bright')

# %%
p = sb.countplot(x='test preparation course', data = data, hue='math_PassStatus', palette='bright')

# %%
p = sb.countplot(x='test preparation course', data = data, hue='read_PassStatus', palette='bright')

# %%
p = sb.countplot(y='parental level of education', data = data, hue='read_PassStatus', palette='bright')

# %%
p = sb.countplot(y='parental level of education', data = data, hue='write_PassStatus', palette='bright')

# %%
p = sb.countplot(x='test preparation course', data = data, hue='write_PassStatus', palette='bright')

# %%
mp.figure(figsize=(30,10))
mp.subplots_adjust(left = 0.0 , bottom = 0.1 , right = 3.0 , top = 0.9 ,wspace = 0.0 , hspace = 0.01)
mp.subplot(251)
mp.title('math score and gender')
sb.countplot(hue = "gender" , x = "math score" , data = data)
mp.show()

# %% [markdown]
# we conclude that the larger females scored 65 in maths and no of males score 100is more than the females
# and larger number of females have scored lesser range marks between 0-27 than males.

# %%
mp.figure(figsize=(30,10))
mp.subplots_adjust(left = 0.0 , bottom = 0.1 , right = 3.0 , top = 0.9 ,wspace = 0.0 , hspace = 0.01)
mp.subplot(251)
mp.title('reading score and gender')
sb.countplot(hue = "gender" , x = "reading score" , data = data)
mp.show()

# %% [markdown]
# we conclude that larger no. of females have scored 72 in reading , and much larger number of females scored full marks in reading than males....

# %%
mp.figure(figsize=(30,10))
mp.subplots_adjust(left = 0.0 , bottom = 0.1 , right = 3.0 , top = 0.9 ,wspace = 0.0 , hspace = 0.01)
mp.subplot(251)
mp.title('writing score and gender')
sb.countplot(hue = "gender" , x = "writing score" , data = data)
mp.show()

# %% [markdown]
# we conclude that larger no. of females have scored 70in writing much largernumber of females scored full marks in reading than males....

# %%
mp.figure(figsize=(30,10))
mp.subplots_adjust(left = 0.0 , bottom = 0.1 , right = 3.0 , top = 0.9 ,wspace = 0.0 , hspace = 0.01)
mp.subplot(251)
mp.title('Parental Level of Educaation and gender')
sb.countplot(hue = "parental level of education" , x = "gender" , data = data)
mp.show()

# %%
mp.figure(figsize=(30,10))
mp.subplots_adjust(left = 0.0 , bottom = 0.1 , right = 3.0 , top = 0.9 ,wspace = 0.0 , hspace = 0.01)
mp.subplot(251)
mp.title('test preparation course and gender')
sb.countplot(hue = "test preparation course" , x = "gender" , data = data)
mp.show()

# %%
mp.figure(figsize=(30,10))
mp.subplots_adjust(left = 0.0 , bottom = 0.1 , right = 3.0 , top = 0.9 ,wspace = 0.0 , hspace = 0.01)
mp.subplot(251)
mp.title('lunch and gender')
sb.countplot(hue = "lunch" , x = "gender" , data = data)
mp.show()

# %%
mp.figure(figsize=(30,10))
mp.subplots_adjust(left = 0.0 , bottom = 0.1 , right = 3.0 , top = 0.9 ,wspace = 0.0 , hspace = 0.01)
mp.subplot(251)
mp.title('race/ethnicity and gender')
sb.countplot(hue = "race/ethnicity" , x = "gender" , data = data)
mp.show()

# %%
mp.figure(figsize=(30,10))
mp.subplots_adjust(left = 0.0 , bottom = 0.1 , right = 3.0 , top = 0.9 ,wspace = 0.0 , hspace = 0.01)
mp.subplot(251)
mp.title('test preparation course and parental level of education')
sb.countplot(hue = "test preparation course" , x = "parental level of education" , data = data)
mp.show()

# %% [markdown]
# almost same trend is followed between the test preparation course and the all level of parental education.

# %%
mp.figure(figsize=(30,10))
mp.subplots_adjust(left = 0.0 , bottom = 0.1 , right = 3.0 , top = 0.9 ,wspace = 0.0 , hspace = 0.01)
mp.subplot(251)
mp.title('race/ethnicity and parental level of education')
sb.countplot(hue = "race/ethnicity" , x = "parental level of education" , data = data)
mp.show()

# %% [markdown]
# group c and group d habing same count in the some college and the some high school level of education.
# huge gap is seen in the associate degreee level of education.

# %%
mp.figure(figsize=(30,10))
mp.subplots_adjust(left = 0.0 , bottom = 0.1 , right = 3.0 , top = 0.9 ,wspace = 0.0 , hspace = 0.01)
mp.subplot(251)
mp.title('test preparation course and lunch')
sb.countplot(hue = "test preparation course" , x = "lunch" , data = data)
mp.show()

# %% [markdown]
# Thanx for reading and analysing
# i tried my best to find the insights of the data we have here and all the inferences that i found are written
# side by side below the graphs and the they also present in the document file attached with...
